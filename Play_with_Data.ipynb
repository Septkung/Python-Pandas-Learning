# %%
import pandas as pd

# %%
df = pd.read_excel("thailand_data.xlsx")

# %%
df
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12           NaT  หญิง  61.0   ปี       China
# 1            2    2020-01-17           NaT  หญิง  74.0   ปี       China
# 2            3    2020-01-22           NaT  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22           NaT   ชาย  68.0   ปี       China
# 4            5    2020-01-24           NaT  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985    2021-08-11    2021-08-10  หญิง   8.0   ปี    Thailand
# 816985  816986    2021-08-11    2021-08-10   ชาย  14.0   ปี    Thailand
# 816986  816987    2021-08-11    2021-08-10   ชาย  59.0   ปี    Thailand
# 816987  816988    2021-08-11    2021-08-10  หญิง  34.0   ปี    Thailand
# 816988  816989    2021-08-11    2021-08-10  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0                    NaN
# 1                    NaN
# 2                  เมือง
# 3                    NaN
# 4                    NaN
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %%
df_II = pd.read_csv("thailand_data.csv")
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9412\95747211.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_II = pd.read_csv("thailand_data.csv")

# %%
df_II
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
d = {'title' : "Fun with Python",
     "price" : 230,
     "author" : "Bob Pres"}

d2 = {"title" : "Intorduction to Python",
      "price" : 230,}

# %%
books = [d,d2]

# %%
books
# Out:
# [{'title': 'Fun with Python', 'price': 230, 'author': 'Bob Pres'},
#  {'title': 'Intorduction to Python', 'price': 230}]

# %%
d["author"]
# Out:
# 'Bob Pres'

# %%
pd.DataFrame(books)
# Out:
#                     title  price    author
# 0         Fun with Python    230  Bob Pres
# 1  Intorduction to Python    230       NaN

# %%
import requests

# %%
result = requests.get("http://api.openweathermap.org/data/2.5/forecast?q=Bangkok,TH&appid=bae1310c685763246ff511b872ecce5a")

# %%
d = result.json()

# %%
Df_III = pd.DataFrame(d["list"])

# %%
Df_III["rain amount"] = Df_III["rain"].str["3h"]
Df_III
# Out:
#             dt                                               main  \
# 0   1755712800  {'temp': 302.3, 'feels_like': 306.02, 'temp_mi...
# 1   1755723600  {'temp': 301.51, 'feels_like': 305.15, 'temp_m...
# 2   1755734400  {'temp': 300.8, 'feels_like': 304.13, 'temp_mi...
# 3   1755745200  {'temp': 303.98, 'feels_like': 308.13, 'temp_m...
# 4   1755756000  {'temp': 307.36, 'feels_like': 311.66, 'temp_m...
# 5   1755766800  {'temp': 306.57, 'feels_like': 310.61, 'temp_m...
# 6   1755777600  {'temp': 303.85, 'feels_like': 307.61, 'temp_m...
# 7   1755788400  {'temp': 302.57, 'feels_like': 305.82, 'temp_m...
# 8   1755799200  {'temp': 301.47, 'feels_like': 304.75, 'temp_m...
# 9   1755810000  {'temp': 300.33, 'feels_like': 303.29, 'temp_m...
# 10  1755820800  {'temp': 298.38, 'feels_like': 299.26, 'temp_m...
# 11  1755831600  {'temp': 301.23, 'feels_like': 304.25, 'temp_m...
# 12  1755842400  {'temp': 301.61, 'feels_like': 304.73, 'temp_m...
# 13  1755853200  {'temp': 302.31, 'feels_like': 305.85, 'temp_m...
# 14  1755864000  {'temp': 300.67, 'feels_like': 303.6, 'temp_mi...
# 15  1755874800  {'temp': 299.9, 'feels_like': 302.67, 'temp_mi...
# 16  1755885600  {'temp': 299.33, 'feels_like': 299.33, 'temp_m...
# 17  1755896400  {'temp': 298.95, 'feels_like': 299.83, 'temp_m...
# 18  1755907200  {'temp': 299.32, 'feels_like': 299.32, 'temp_m...
# 19  1755918000  {'temp': 303.05, 'feels_like': 306.82, 'temp_m...
# 20  1755928800  {'temp': 304.06, 'feels_like': 308.3, 'temp_mi...
# 21  1755939600  {'temp': 300.8, 'feels_like': 304.26, 'temp_mi...
# 22  1755950400  {'temp': 299.4, 'feels_like': 299.4, 'temp_min...
# 23  1755961200  {'temp': 297.62, 'feels_like': 298.52, 'temp_m...
# 24  1755972000  {'temp': 297.92, 'feels_like': 298.78, 'temp_m...
# 25  1755982800  {'temp': 298.03, 'feels_like': 298.9, 'temp_mi...
# 26  1755993600  {'temp': 298.35, 'feels_like': 299.22, 'temp_m...
# 27  1756004400  {'temp': 299.23, 'feels_like': 299.23, 'temp_m...
# 28  1756015200  {'temp': 301.68, 'feels_like': 305.54, 'temp_m...
# 29  1756026000  {'temp': 300.77, 'feels_like': 304.32, 'temp_m...
# 30  1756036800  {'temp': 298.88, 'feels_like': 299.81, 'temp_m...
# 31  1756047600  {'temp': 298.52, 'feels_like': 299.44, 'temp_m...
# 32  1756058400  {'temp': 298.19, 'feels_like': 299.15, 'temp_m...
# 33  1756069200  {'temp': 298.17, 'feels_like': 299.05, 'temp_m...
# 34  1756080000  {'temp': 298.34, 'feels_like': 299.19, 'temp_m...
# 35  1756090800  {'temp': 300.8, 'feels_like': 303.51, 'temp_mi...
# 36  1756101600  {'temp': 302.22, 'feels_like': 306.03, 'temp_m...
# 37  1756112400  {'temp': 300.8, 'feels_like': 304.13, 'temp_mi...
# 38  1756123200  {'temp': 299.05, 'feels_like': 299.89, 'temp_m...
# 39  1756134000  {'temp': 298.29, 'feels_like': 299.18, 'temp_m...
#
#                                               weather        clouds  \
# 0   [{'id': 500, 'main': 'Rain', 'description': 'l...   {'all': 96}
# 1   [{'id': 500, 'main': 'Rain', 'description': 'l...   {'all': 98}
# 2   [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 3   [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 4   [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 5   [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 97}
# 6   [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 99}
# 7   [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 8   [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 9   [{'id': 501, 'main': 'Rain', 'description': 'm...  {'all': 100}
# 10  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 11  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 12  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 13  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 14  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 15  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 16  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 17  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 18  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 19  [{'id': 500, 'main': 'Rain', 'description': 'l...   {'all': 84}
# 20  [{'id': 500, 'main': 'Rain', 'description': 'l...   {'all': 85}
# 21  [{'id': 501, 'main': 'Rain', 'description': 'm...  {'all': 100}
# 22  [{'id': 501, 'main': 'Rain', 'description': 'm...  {'all': 100}
# 23  [{'id': 501, 'main': 'Rain', 'description': 'm...  {'all': 100}
# 24  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 25  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 26  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 27  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 28  [{'id': 500, 'main': 'Rain', 'description': 'l...   {'all': 95}
# 29  [{'id': 501, 'main': 'Rain', 'description': 'm...  {'all': 100}
# 30  [{'id': 501, 'main': 'Rain', 'description': 'm...  {'all': 100}
# 31  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 32  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 33  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 34  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 35  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 36  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 37  [{'id': 501, 'main': 'Rain', 'description': 'm...  {'all': 100}
# 38  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 39  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
#
#                                          wind  visibility   pop          rain  \
# 0   {'speed': 2.21, 'deg': 186, 'gust': 4.14}       10000  0.23  {'3h': 0.25}
# 1   {'speed': 1.08, 'deg': 209, 'gust': 1.45}       10000  1.00  {'3h': 2.89}
# 2   {'speed': 0.77, 'deg': 330, 'gust': 0.96}       10000  0.80           NaN
# 3   {'speed': 0.86, 'deg': 105, 'gust': 1.01}       10000  0.00           NaN
# 4   {'speed': 1.18, 'deg': 193, 'gust': 1.41}       10000  0.00           NaN
# 5   {'speed': 3.87, 'deg': 168, 'gust': 2.84}       10000  0.00           NaN
# 6    {'speed': 4.7, 'deg': 167, 'gust': 5.85}       10000  0.00           NaN
# 7   {'speed': 4.13, 'deg': 178, 'gust': 6.49}       10000  0.38           NaN
# 8    {'speed': 3.3, 'deg': 156, 'gust': 6.11}       10000  0.82  {'3h': 1.05}
# 9   {'speed': 2.05, 'deg': 194, 'gust': 4.66}       10000  1.00  {'3h': 4.54}
# 10  {'speed': 2.48, 'deg': 267, 'gust': 4.32}       10000  1.00  {'3h': 1.84}
# 11     {'speed': 2, 'deg': 251, 'gust': 2.81}       10000  1.00  {'3h': 2.63}
# 12   {'speed': 3.21, 'deg': 174, 'gust': 3.8}       10000  0.80           NaN
# 13     {'speed': 4.65, 'deg': 171, 'gust': 5}       10000  0.00           NaN
# 14  {'speed': 2.66, 'deg': 187, 'gust': 5.94}        6253  0.36   {'3h': 0.4}
# 15  {'speed': 2.11, 'deg': 276, 'gust': 4.77}       10000  1.00  {'3h': 2.83}
# 16   {'speed': 0.7, 'deg': 253, 'gust': 1.66}       10000  0.80           NaN
# 17  {'speed': 1.41, 'deg': 222, 'gust': 2.69}       10000  0.20  {'3h': 0.26}
# 18  {'speed': 1.14, 'deg': 239, 'gust': 2.17}       10000  0.00           NaN
# 19  {'speed': 1.65, 'deg': 242, 'gust': 2.37}       10000  0.56  {'3h': 0.57}
# 20  {'speed': 2.33, 'deg': 192, 'gust': 2.39}        6158  1.00  {'3h': 2.58}
# 21  {'speed': 3.83, 'deg': 166, 'gust': 5.43}        7889  1.00  {'3h': 4.86}
# 22   {'speed': 4.3, 'deg': 196, 'gust': 8.34}        6076  1.00  {'3h': 4.03}
# 23  {'speed': 4.23, 'deg': 246, 'gust': 9.31}       10000  1.00  {'3h': 3.24}
# 24  {'speed': 1.55, 'deg': 246, 'gust': 4.67}       10000  1.00  {'3h': 0.27}
# 25  {'speed': 0.58, 'deg': 141, 'gust': 0.97}       10000  0.22           NaN
# 26  {'speed': 1.61, 'deg': 162, 'gust': 2.31}        9176  1.00  {'3h': 2.38}
# 27  {'speed': 1.91, 'deg': 186, 'gust': 2.65}       10000  1.00  {'3h': 2.01}
# 28  {'speed': 2.72, 'deg': 208, 'gust': 3.43}        8119  1.00   {'3h': 2.3}
# 29  {'speed': 2.65, 'deg': 223, 'gust': 4.33}        6957  1.00  {'3h': 4.62}
# 30  {'speed': 1.35, 'deg': 193, 'gust': 3.32}       10000  1.00  {'3h': 3.72}
# 31  {'speed': 2.28, 'deg': 210, 'gust': 6.19}       10000  1.00  {'3h': 1.59}
# 32   {'speed': 2.62, 'deg': 170, 'gust': 5.5}       10000  1.00  {'3h': 1.29}
# 33   {'speed': 1.9, 'deg': 201, 'gust': 4.78}       10000  0.89  {'3h': 1.65}
# 34  {'speed': 0.88, 'deg': 225, 'gust': 1.32}       10000  0.84  {'3h': 0.72}
# 35   {'speed': 1.31, 'deg': 255, 'gust': 2.6}       10000  0.39  {'3h': 0.24}
# 36  {'speed': 1.73, 'deg': 241, 'gust': 2.98}        6311  1.00  {'3h': 2.01}
# 37   {'speed': 3.48, 'deg': 222, 'gust': 4.8}       10000  1.00   {'3h': 3.9}
# 38  {'speed': 4.35, 'deg': 231, 'gust': 8.96}       10000  1.00  {'3h': 1.95}
# 39    {'speed': 3.4, 'deg': 228, 'gust': 8.6}       10000  0.28  {'3h': 0.15}
#
#              sys               dt_txt  rain amount
# 0   {'pod': 'n'}  2025-08-20 18:00:00         0.25
# 1   {'pod': 'n'}  2025-08-20 21:00:00         2.89
# 2   {'pod': 'd'}  2025-08-21 00:00:00          NaN
# 3   {'pod': 'd'}  2025-08-21 03:00:00          NaN
# 4   {'pod': 'd'}  2025-08-21 06:00:00          NaN
# 5   {'pod': 'd'}  2025-08-21 09:00:00          NaN
# 6   {'pod': 'n'}  2025-08-21 12:00:00          NaN
# 7   {'pod': 'n'}  2025-08-21 15:00:00          NaN
# 8   {'pod': 'n'}  2025-08-21 18:00:00         1.05
# 9   {'pod': 'n'}  2025-08-21 21:00:00         4.54
# 10  {'pod': 'd'}  2025-08-22 00:00:00         1.84
# 11  {'pod': 'd'}  2025-08-22 03:00:00         2.63
# 12  {'pod': 'd'}  2025-08-22 06:00:00          NaN
# 13  {'pod': 'd'}  2025-08-22 09:00:00          NaN
# 14  {'pod': 'n'}  2025-08-22 12:00:00         0.40
# 15  {'pod': 'n'}  2025-08-22 15:00:00         2.83
# 16  {'pod': 'n'}  2025-08-22 18:00:00          NaN
# 17  {'pod': 'n'}  2025-08-22 21:00:00         0.26
# 18  {'pod': 'd'}  2025-08-23 00:00:00          NaN
# 19  {'pod': 'd'}  2025-08-23 03:00:00         0.57
# 20  {'pod': 'd'}  2025-08-23 06:00:00         2.58
# 21  {'pod': 'd'}  2025-08-23 09:00:00         4.86
# 22  {'pod': 'n'}  2025-08-23 12:00:00         4.03
# 23  {'pod': 'n'}  2025-08-23 15:00:00         3.24
# 24  {'pod': 'n'}  2025-08-23 18:00:00         0.27
# 25  {'pod': 'n'}  2025-08-23 21:00:00          NaN
# 26  {'pod': 'd'}  2025-08-24 00:00:00         2.38
# 27  {'pod': 'd'}  2025-08-24 03:00:00         2.01
# 28  {'pod': 'd'}  2025-08-24 06:00:00         2.30
# 29  {'pod': 'd'}  2025-08-24 09:00:00         4.62
# 30  {'pod': 'n'}  2025-08-24 12:00:00         3.72
# 31  {'pod': 'n'}  2025-08-24 15:00:00         1.59
# 32  {'pod': 'n'}  2025-08-24 18:00:00         1.29
# 33  {'pod': 'n'}  2025-08-24 21:00:00         1.65
# 34  {'pod': 'd'}  2025-08-25 00:00:00         0.72
# 35  {'pod': 'd'}  2025-08-25 03:00:00         0.24
# 36  {'pod': 'd'}  2025-08-25 06:00:00         2.01
# 37  {'pod': 'd'}  2025-08-25 09:00:00         3.90
# 38  {'pod': 'n'}  2025-08-25 12:00:00         1.95
# 39  {'pod': 'n'}  2025-08-25 15:00:00         0.15
