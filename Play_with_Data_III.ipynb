# %%
import pandas as pd 

df = pd.read_excel('-30-uc-.xlsx',skiprows=3,skipfooter=15)
df
# Out:
#                                            Unnamed: 0        Unnamed: 1  \
# 0                                     เขต 1 เชียงใหม่         เชียงใหม่
# 1                                                 NaN             ลำพูน
# 2                                                 NaN             ลำปาง
# 3                                                 NaN              แพร่
# 4                                                 NaN              น่าน
# ..                                                ...               ...
# 73                                                NaN           ปัตตานี
# 74                                                NaN              ยะลา
# 75                                                NaN          นราธิวาส
# 76                               เขต 13 กรุงเทพมหานคร          กรุงเทพฯ
# 77  เขต 14 กรมแพทย์ทหารเรือ, กรมแพทย์ทหารอากาศ, ทั...  กรมแพทย์ทหารเรือ
#
#     ตัวตั้ง (จังหวัด)  ตัวหาร (จังหวัด)  ผลลัพธ์ (จังหวัด)  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'ตัวตั้ง (จังหวัด)', 'ตัวหาร (จังหวัด)',
#        'ผลลัพธ์ (จังหวัด)', 'จำนวนครั้ง (จังหวัด)', 'ตัวตั้ง (จังหวัด).1',
#        'ตัวหาร (จังหวัด).1', 'ผลลัพธ์ (จังหวัด).1', 'จำนวนครั้ง (จังหวัด).1',
#        'ตัวตั้ง (จังหวัด).2', 'ตัวหาร (จังหวัด).2', 'ผลลัพธ์ (จังหวัด).2',
#        'จำนวนครั้ง (จังหวัด).2', 'ตัวตั้ง (จังหวัด).3', 'ตัวหาร (จังหวัด).3',
#        'ผลลัพธ์ (จังหวัด).3', 'จำนวนครั้ง (จังหวัด).3'],
#       dtype='object')

# %%
df.columns = ['เขต',"จังหวัด"] + list(df.columns[2:])
df
# Out:
#                                                   เขต           จังหวัด  \
# 0                                     เขต 1 เชียงใหม่         เชียงใหม่
# 1                                                 NaN             ลำพูน
# 2                                                 NaN             ลำปาง
# 3                                                 NaN              แพร่
# 4                                                 NaN              น่าน
# ..                                                ...               ...
# 73                                                NaN           ปัตตานี
# 74                                                NaN              ยะลา
# 75                                                NaN          นราธิวาส
# 76                               เขต 13 กรุงเทพมหานคร          กรุงเทพฯ
# 77  เขต 14 กรมแพทย์ทหารเรือ, กรมแพทย์ทหารอากาศ, ทั...  กรมแพทย์ทหารเรือ
#
#     ตัวตั้ง (จังหวัด)  ตัวหาร (จังหวัด)  ผลลัพธ์ (จังหวัด)  \
# ...
