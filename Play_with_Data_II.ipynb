# %%
import pandas as pd

# %%
df = pd.read_excel("-30-uc-.xlsx",skiprows=3,skipfooter=15)

# %%
df.columns = ['เขต', 'จังหวัด', '2560: ตัวตั้ง (จังหวัด)', '2560: ตัวหาร (จังหวัด)',
       '2560: ผลลัพธ์ (จังหวัด)', '2560: จำนวนครั้ง (จังหวัด)', '2561: ตัวตั้ง (จังหวัด)',
       '2561: ตัวหาร (จังหวัด)', '2561: ผลลัพธ์ (จังหวัด)', '2561: จำนวนครั้ง (จังหวัด)',
       '2562: ตัวตั้ง (จังหวัด)', '2562: ตัวหาร (จังหวัด)', '2562: ผลลัพธ์ (จังหวัด)',
       '2562: จำนวนครั้ง (จังหวัด)', '2563: ตัวตั้ง (จังหวัด)', '2563: ตัวหาร (จังหวัด)',
       '2563: ผลลัพธ์ (จังหวัด)', '2563: จำนวนครั้ง (จังหวัด)']

# %%
df
# Out:
#                                                   เขต           จังหวัด  \
# 0                                     เขต 1 เชียงใหม่         เชียงใหม่
# 1                                                 NaN             ลำพูน
# 2                                                 NaN             ลำปาง
# 3                                                 NaN              แพร่
# 4                                                 NaN              น่าน
# ..                                                ...               ...
# 73                                                NaN           ปัตตานี
# 74                                                NaN              ยะลา
# 75                                                NaN          นราธิวาส
# 76                               เขต 13 กรุงเทพมหานคร          กรุงเทพฯ
# 77  เขต 14 กรมแพทย์ทหารเรือ, กรมแพทย์ทหารอากาศ, ทั...  กรมแพทย์ทหารเรือ
#
#     2560: ตัวตั้ง (จังหวัด)  2560: ตัวหาร (จังหวัด)  2560: ผลลัพธ์ (จังหวัด)  \
# ...

# %%
data = [[1,1,2,1],[1,2,None,1],[1,2,4,3]]

# %%
df_II = pd.DataFrame(data)
df_II
# Out:
#    0  1    2  3
# 0  1  1  2.0  1
# 1  1  2  NaN  1
# 2  1  2  4.0  3

# %%
df_II.columns=["Attribute_I","Attribute_II","Attribute_II","Attribute_IV"]
df_II
# Out:
#    Attribute_I  Attribute_II  Attribute_II  Attribute_IV
# 0            1             1           2.0             1
# 1            1             2           NaN             1
# 2            1             2           4.0             3

# %%
data2= [{"Attribute_I":1,"Attribute_II":1,"Attribute_III":2,"Attribute_IV":1},
       {"Attribute_I":1,"Attribute_II":2,"Attribute_IV":1},
       {"Attribute_I":1,"Attribute_II":2,"Attribute_III":3,"Attribute_IV":4},]

# %%
df_III = pd.DataFrame(data2)
df_III
# Out:
#    Attribute_I  Attribute_II  Attribute_III  Attribute_IV
# 0            1             1            2.0             1
# 1            1             2            NaN             1
# 2            1             2            3.0             4

# %%
import numpy as np

# %%
df_IV = pd.DataFrame(np.random.random((3,4)),columns = ["Attribute_I","Attribute_II","Attribute_II","Attribute_IV"])
df_IV
# Out:
#    Attribute_I  Attribute_II  Attribute_II  Attribute_IV
# 0     0.262230      0.328586      0.746978      0.846897
# 1     0.630002      0.348901      0.555532      0.430981
# 2     0.973729      0.219708      0.329361      0.026563

# %%
df_V = pd.DataFrame()
